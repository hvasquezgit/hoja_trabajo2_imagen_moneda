# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#img = cv2.imread("C:/Users/hvasquez/Downloads/papa2.jpg")
img = cv2.imread("C:/Users/hevas/Downloads/Papa/papa1.jpg")
#imagen = cv2.imread("C:/Users/hvasquez/Downloads/papa2.jpg")

# %%
plt.imshow(img)
plt.show()

# %%
#gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
_,binary = cv2.threshold(gray,100,255,cv2.THRESH_BINARY)
plt.imshow(binary)

# %%
contours,hierarchy = cv2.findContours(binary,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
drawing = np.zeros((gray.shape[0], gray.shape[1], 3), dtype=np.uint8)
CountersImg = cv2.drawContours(drawing,contours, -1, (0,255,0),3)
plt.imshow(CountersImg)
cv2.waitKey(0)
# Out:
# -1

# %%
#pruebas

# %%
img = cv2.imread("C:/Users/hevas/Downloads/Papa/papa10.jpg")
imagen = cv2.imread("C:/Users/hevas/Downloads/Papa/papa11.jpg")

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
plt.imshow(img)
plt.show()

# %%
#gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
_,binary = cv2.threshold(gray,100,255,cv2.THRESH_BINARY)
plt.imshow(binary)

# %%
contours,hierarchy = cv2.findContours(binary,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
drawing = np.zeros((gray.shape[0], gray.shape[1], 3), dtype=np.uint8)
CountersImg = cv2.drawContours(drawing,contours, -1, (0,255,0),3)
plt.imshow(CountersImg)

# %%
cv2.waitKey(0)

# %%
# Convertimos en escala de grise
gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)

# %%
# Aplicar suavizado Gaussiano
gaussiana = cv2.GaussianBlur(gris, (5,5), 0)

# %%
# Convertimos a escala de grises
gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
 
# Aplicar suavizado Gaussiano
gauss = cv2.GaussianBlur(gris, (5,5), 0)
 
#cv2.imshow("suavizado", gauss)
plt.imshow(gauss)

# %%
# Detectamos los bordes con Canny
canny = cv2.Canny(gauss, 50, 150)
 
#cv2.imshow("canny", canny)
plt.imshow(canny)

# %%
# Buscamos los contornos
(contornos,_) = cv2.findContours(canny.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
 
# Mostramos el número de monedas por consola
print("He encontrado {} objetos".format(len(contornos)))
 
cv2.drawContours(imagen,contornos,-1,(0,0,255), 2)
#cv2.imshow("contornos", original)
plt.imshow(imagen)
cv2.waitKey(0)

# %%
alto = img.shape[0]
ancho = img.shape[1]

# %%
lienzo = np.zeros((alto, ancho, 3)) # resultado a color.

# %%
for i in range(0, alto):
    for j in range(0, ancho):
        pixel = img[i, j]
        
        blue  = pixel[2]
        green = pixel[1]
        red   = pixel[0]
        
        lienzo[i, j] = [blue, 0, 0]

# %%
media_ponderada = np.zeros((alto, ancho, 1)) # escala de grises

# %%
for i in range(0, alto):
    for j in range(0, ancho):
        pixel = img[i, j]
        
        blue  = pixel[2]
        green = pixel[1]
        red   = pixel[0]
        
        media_ponderada[i, j] = int(0.299* blue + 0.58 * green + 0.114 * red)

# %%
cv2.imwrite("gris_ponderado.jpg", media_ponderada)
gris = cv2.imread("gris_ponderado.jpg")
gris = cv2.cvtColor(gris, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(gris)
plt.show()

# %%
# Convertimos a escala de grises
#gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
 
# Aplicar suavizado Gaussiano
gauss = cv2.GaussianBlur(gris, (5,5), 0)
 
#cv2.imshow("suavizado", gauss)
plt.imshow(gauss)
 
# Detectamos los bordes con Canny
canny = cv2.Canny(gauss, 50, 150)
canny = cv2.dilate(canny,None, iterations = 1)
canny = cv2.erode(canny,None, iterations=1)

 
#cv2.imshow("canny", canny)
plt.imshow(canny)
 
# Buscamos los contornos
#(contornos,_) = cv2.findContours(canny.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
(contornos,_) = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
 
# Mostramos el número de monedas por consola
print("He encontrado {} objetos".format(len(contornos)))
 
cv2.drawContours(original,contornos,-1,(0,255,0), 2)
#cv2.imshow("contornos", imagen)
plt.imshow(imagen)
 
cv2.waitKey(0)
# Out:
# He encontrado 1218 objetos
# -1

# %%
# Detectamos los bordes con Canny
canny = cv2.Canny(gris, 10, 50)
#canny = cv2.dilate(canny,None, iterations = 1)
#canny = cv2.erode(canny,None, iterations=1)
plt.imshow(canny)

# %%
import numpy as np
import cv2
 
# Cargamos la imagen
original = cv2.imread("imagenes/monedas.jpg")
#cv2.imshow("original", imagen)
plt.imshow(imagen)
 
# Convertimos a escala de grises
gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
 
# Aplicar suavizado Gaussiano
gauss = cv2.GaussianBlur(gris, (5,5), 0)
 
#cv2.imshow("suavizado", gauss)
plt.imshow(gauss)
 
# Detectamos los bordes con Canny
canny = cv2.Canny(gauss, 50, 150)
 
#cv2.imshow("canny", canny)
plt.imshow(canny)
 
# Buscamos los contornos
(contornos,_) = cv2.findContours(canny.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
 
# Mostramos el número de monedas por consola
print("He encontrado {} objetos".format(len(contornos)))
 
cv2.drawContours(original,contornos,-1,(0,255,0), 2)
#cv2.imshow("contornos", imagen)
plt.imshow(imagen)
 
cv2.waitKey(0)
# Out:
# He encontrado 3391 objetos
# -1
